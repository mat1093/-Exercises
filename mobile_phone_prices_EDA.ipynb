# %%
pwd
# Out:
# 'C:\\Users\\mkepa'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("C:\\Users\\mkepa\\Downloads\\train.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
data.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
data.groupby('price_range')

# %%
gruped_data=data.groupby('price_range')

# %%
gruped_data.mean()
# Out:
#              battery_power   blue  clock_speed  dual_sim     fc  four_g  \
# price_range
# 0                 1116.902  0.486       1.5502     0.500  4.084   0.518
# 1                 1228.868  0.490       1.4886     0.510  4.340   0.524
# 2                 1228.320  0.486       1.5298     0.498  4.498   0.494
# 3                 1379.984  0.518       1.5204     0.530  4.316   0.550
#
#              int_memory   m_dep  mobile_wt  n_cores      pc  px_height  \
# price_range
# 0                31.174  0.4902    140.552    4.600   9.574    536.408
# 1                32.116  0.5240    140.510    4.298   9.924    666.892
# 2                30.920  0.4908    143.614    4.682  10.018    632.284
# 3                33.976  0.5020    136.320    4.502  10.150    744.848
#
#              px_width       ram    sc_h   sc_w  talk_time  three_g  \
# price_range
# 0            1150.270   785.314  12.324  5.682     10.612    0.746
# 1            1251.908  1679.490  12.212  5.544     11.362    0.756
# ...

# %%
grouped_data=pd.DataFrame(gruped_data.mean())

# %%
grouped_data[['battery_power','clock_speed','ram']].plot.bar()

# %%
sns.pairplot(data[['price_range','battery_power','clock_speed','ram','fc']],hue='price_range')

# %%
sns.boxplot(x='price_range',y='battery_power',data=data)

# %%
sns.boxplot(x='price_range',y='ram',data=data)

# %%
df_num=data.select_dtypes(include = ['float64', 'int64'])

# %%
cat_var = ['blue','dual_sim','four_g','three_g','touch_screen','price_range']

# %%
fig=plt.figure(figsize=(15,15))
for i,var in enumerate(cat_var):
    ax=plt.subplot(3,2,i+1)
    sns.countplot(data[var],ax=ax)
    plt.xlabel(var)

# %%
num_var = ['battery_power','clock_speed','fc','int_memory','m_dep','mobile_wt', 'n_cores', 'pc', 'px_height',
             'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time']

# %%
fig=plt.figure(figsize=(15,20))
for i,var in enumerate(num_var):
    ax=plt.subplot(5,3,i+1,)
    sns.distplot(data[var],ax=ax,bins=15)
plt.show()

# %%
mtrx
# Out:
#                battery_power  clock_speed       ram        fc
# battery_power       1.000000     0.011482 -0.000653  0.033334
# clock_speed         0.011482     1.000000  0.003443 -0.000434
# ram                -0.000653     0.003443  1.000000  0.015099
# fc                  0.033334    -0.000434  0.015099  1.000000

# %%
mtrx=data.iloc[:,:-1].corr()
f, axs = plt.subplots(1,1,figsize=(15,15))
sns.heatmap(mtrx[(mtrx>0.5) | (mtrx<-0.4)],cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size": 8}, square=True)

# %%
fourG=mtrx['four_g']

# %%
fourG.drop('four_g',inplace=True)

# %%
significant_corr=fourG[abs(fourG)>0.4].sort_values(ascending=False)

# %%
print("{} strong correlations with 4G:\n{}".format(len(significant_corr), significant_corr ))
# Out:
# 1 strong correlations with 4G:
# three_g    0.584246
# Name: four_g, dtype: float64

# %%
data[data.duplicated()].sum()
# Out:
# battery_power    0.0
# blue             0.0
# clock_speed      0.0
# dual_sim         0.0
# fc               0.0
# four_g           0.0
# int_memory       0.0
# m_dep            0.0
# mobile_wt        0.0
# n_cores          0.0
# pc               0.0
# px_height        0.0
# px_width         0.0
# ram              0.0
# sc_h             0.0
# sc_w             0.0
# talk_time        0.0
# three_g          0.0
# touch_screen     0.0
# wifi             0.0
# price_range      0.0
# dtype: float64

# %%
## check outliers
